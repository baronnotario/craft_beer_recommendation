# %% [markdown]
# # Input Beer Recommender Engine

# %% [markdown]
# ## In this notebook we make an item based recommender system to input a BEER which likes one user and GET the TOP 5 SIMILAR BEERS

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot
# %matplotlib inline
import sys
reload(sys)
sys.setdefaultencoding("utf-8")

# %%
df = pd.read_csv('df_to_recommender.csv')

# %%
df.shape
# Out:
# (7771, 27)

# %%
rated = df.num_rated_beers
stats = rated.describe()
stats
# Out:
# count    7771.000000
# mean      951.726161
# std       411.347573
# min       501.000000
# 25%       649.000000
# 50%       837.000000
# 75%      1161.000000
# max      2197.000000
# Name: num_rated_beers, dtype: float64

# %%
df=df[['user_id', 'profile_name', 'Id', 'names', 'num_rated_beers', 'style','overall']].copy()

# %%
ratings = df.pivot_table(values='overall', index='user_id', columns='names')
ratings.fillna(0, inplace=True)
beer_index = ratings.columns
ratings.shape
# Out:
# (214, 7205)

# %%
ratings.head()
# Out:
# names     $ellout $tout   'Tis The Saison   'Zula Stout  \
# user_id
# 491                 0.0               0.0           0.0
# 594                 0.0               0.0           0.0
# 977                 0.0               0.0           0.0
# 1198                0.0               0.0           0.0
# 1214                0.0               0.0           0.0
#
# names     't Gaverhopke Zingende Blondine   't Smisje Blond   't Smisje Fiori  \
# user_id
# 491                                   0.0               0.0               0.0
# 594                                   0.0               0.0               0.0
# 977                                   0.0               0.0               0.0
# 1198                                  0.0               0.0               0.0
# 1214                                  0.0               0.0               0.0
#
# names     't Smisje Grande Reserva   't Smisje Great Reserva  \
# user_id
# 491                            0.0                       0.0
# 594                            0.0                       0.0
# 977                            0.0                       0.0
# 1198                           0.0                       0.0
# 1214                           0.0                       0.0
#
# names     't Smisje Tripel   (512) Cascabel Cream Stout  \
# user_id
# 491                    0.0                          0.0
# 594                    0.0                          0.0
# 977                    0.0                          0.0
# 1198                   0.0                          0.0
# 1214                   0.0                          0.0
#
# names                          ...                         \
# user_id                        ...
# 491                            ...
# 594                            ...
# 977                            ...
# 1198                           ...
# 1214                           ...
#
# names    " La Malagne (for Archaeopark, Rochefort)"  \
# user_id
# 491                                             0.0
# 594                                             0.0
# 977                                             0.0
# 1198                                            0.0
# 1214                                            0.0
#
# names    " Mischief, Double Dry-Hopped"  " Nice Guy, Dud Root"  \
# user_id
# 491                                 0.0                    0.0
# 594                                 0.0                    0.0
# 977                                 0.0                    0.0
# 1198                                0.0                    0.0
# 1214                                0.0                    0.0
#
# names    " Saison De Lente, 100% Brett"  \
# user_id
# 491                                 0.0
# 594                                 0.0
# 977                                 0.0
# 1198                                0.0
# 1214                                0.0
#
# names    " Schell's Anniversary Series #8, 1905 V.T. (Vacuum Tonic)"  \
# user_id
# 491                                                    0.0
# 594                                                    0.0
# 977                                                    0.0
# 1198                                                   0.0
# 1214                                                   0.0
#
# names    " Schlafly ""Sofa King"" Red Ale"  \
# user_id
# 491                                    0.0
# 594                                    0.0
# 977                                    0.0
# 1198                                   0.0
# 1214                                   0.0
#
# names    " Schlafly #20, Volume 1 - Imperial Pilsner"  \
# user_id
# 491                                               0.0
# 594                                               0.0
# 977                                               0.0
# 1198                                              0.0
# 1214                                              0.0
#
# names    " Tovarish With Cacao, Toasted Almond & Coconut"  \
# user_id
# 491                                                   0.0
# 594                                                   0.0
# 977                                                   0.0
# 1198                                                  0.0
# 1214                                                  0.0
#
# names    " Upright (""Punk Rock"" Strong) Lager"  \
# user_id
# 491                                          0.0
# 594                                          0.0
# 977                                          0.0
# 1198                                         0.0
# 1214                                         0.0
#
# names    " Zeppelin (for Den Ouden Advokaat, St.Pauwels)"
# user_id
# 491                                                   0.0
# 594                                                   0.0
# 977                                                   0.0
# 1198                                                  0.0
# 1214                                                  0.0
#
# [5 rows x 7205 columns]

# %%
corr_matrix= np.corrcoef(ratings.T)
corr_matrix.shape
# Out:
# (7205, 7205)

# %%
def get_top_beers (a):
    favoured_beer_index = list(beer_index).index(a)
    P = corr_matrix[favoured_beer_index]
#solo devolvemos las cervezas con la mayor correlación con bearded Pat's Barleywin
    return(list(beer_index[(P>0.5) & (P<1.0)][:5]))

# %% [markdown]
# ### Check the function

# %%
get_top_beers(' Orange Blossom')
# Out:
# [' Big Ben Double IPA',
#  ' Black Sin',
#  ' Columbus Red',
#  ' Double IPA Version 2',
#  ' Fresh Hop 2009']

# %% [markdown]
# ### Make a dropdown list application

# %%
import ipywidgets as widgets
from ipywidgets import interactive
 
items = sorted(df['names'].unique().tolist())

def view(x=''):
    if x==x: return(get_top_beers(x))
     
    
w = widgets.Select(options=items)
interactive(view, x=w)
# Out:
# interactive(children=(Select(description=u'x', options=(' $ellout $tout', " 'Tis The Saison", " 'Zula Stout", " 't Gaverhopke Zingende Blondine", " 't Smisje Blond", " 't Smisje Fiori", " 't Smisje Grande Reserva", " 't Smisje Great Reserva", " 't Smisje Tripel", ' (512) Cascabel Cream Stout', ' (512) TWO', ' (512) Whiskey Barrel Aged Double Pecan Porter', ' (512) Wit', ' 0% Brett Saison De Lente', " 06 Old Ton O' Bricks Barleywine", ' 1 A.M. Ale', ' 10th Anniversary Bock-style Red Fox', ' 10th Great British Beer Festival Anniversary Ale', ' 11th Anniversary Double IPA', ' 12 Gauge Stout', ' 120 Shilling Ale', ' 1488 Whisky Beer', ' 14th Anniversary Ale', ' 150th Anniversary All Malt Lager', ' 15th Anniversary Ale', ' 15th Anniversary ESB', ' 16 Year Anniversary Ale', ' 1633 Original Dunkel', ' 1673', ' 18', ' 1803 Fat Ox Ale', ' 1849 Irish Red Ale', ' 1856 IPA', ' 1878 Einbecker Doppelbock', ' 18th Street Pale Ale', ' 1900 Sp\xc3\xa9ciale Bonnes F\xc3\xaates', ' 1914 Porter', ' 1984 Golden Ale', ' 19th Anniversary ESB', ' 2003 Yo-Ho Barleywine', ' 2004 Symposium Ale', ' 2006 Double Bastard Ale Aged In Brandy Barrels', ' 2008 Christmas Ale', ' 2009 Christmas Ale', ' 2010 Reserve Old Boardhead Barley Wine Ale', ' 2011 Christmas Ale', ' 2011 Owens Valley Wet Harvest Lager', ' 2011 Reserve Pale Ale', ' 20th Anniversary', ' 20th Street Green Hop Ale', ' 21 Bones Salute ESB', ' 219', ' 21st